# %%
import json
import time
import dateutil.parser
import numpy as np
import multiprocessing as mp
import redis
import string
import collections
from Queue import Empty
import itertools

# %% [markdown]
# 1. Go to https://dev.twitter.com/
# 2. Click on "Sign In" in the upper-right corner.
#     * There is a link to sign up under the username field if you do not already have a Twitter account.
#     * If you sign up for a new account, you'll have to confirm your email before you can get an API key.
# 3. Enter your credentials and sign in.
# 4. Back at https://dev.twitter.com/, click on your avatar in the upper-right corner, then My Applications.
# 5. Click on "Create a new application".
# 6. Fill out the information, agree to the Rules of the Road, do the captcha, and click on "Create your Twitter application".
# 7. In the application page that comes up next, copy down the "Consumer key" and "Consumer secret". This is half of the key info.
# 8. Click on "Create my access token" at the bottom of the application page, under "Your access token".
# 9. (You may have to refresh the page first) Now under "Your access token", copy down your "Access token" and "Access token secret".
# 10. Back in the iPython notebook, paste these four alphanumeric values into the appropriate fields of the twitter.OAuth object.
#
# https://dev.twitter.com/docs/api/1.1

# %%
import twitter

#This is private data. Don't re-share this notebook with your keys here.
t = twitter.Twitter(auth=twitter.OAuth(
        token="2595937920-fH4Us87NVBD8W2JyiHSp0K54XDGSSNvveIMtCjy",
        token_secret="amj8b1a93V9h9d6UnKRxx8621b9YXaq011w6kyNgzpsb9",
        consumer_key="wXlIw7WuUPO7NqeNy7SNqAiIO",
        consumer_secret="oQmDI1CB9r9pH7J310JRmKWAty5LsoGSyWzuYyCwy5m2UKENAE"))
#stream = twitter_stream.statuses.sample(block=True)

#testing = stream.next() # This is just to make sure the stream is emitting data.

# %%
r = t.statuses.user_timeline(screen_name="marcoruffo85", count=10) #max number of counts

# %%
len(r)
# Out:
# 10

# %%
import time

# %%
time.sleep(1)

# %%
followers = t.followers.ids(screen_name="marcoruffo85")
len(followers['ids']) #106
# Out:
# 107

# %%
following = t.friends.ids(screen_name="marcoruffo85")
len(following['ids']) #232
# Out:
# 232

# %%
len(set(followers['ids']) & set(following['ids']))
# Out:
# 86

# %%
ego_network = {}

# %%
for ids in followers['ids'][:5]:
    if ids not in ego_network:
        time.sleep(60)
        f = t.followers.ids(user_id=ids)['ids']
        ego_network[ids] = f
        print(ids, len(f))

# %%
300/15
# Out:
# 20

# %%
ego_network.keys()
# Out:
# [2595937920, 287314714, 403122124, 2588171150, 399582775]

# %%
len(total&set(followers['ids']))
# Out:
# 16

# %%
t.users.show(user_id=1647251948)
# Out:
# {u'contributors_enabled': False,
#  u'created_at': u'Mon Aug 05 08:06:21 +0000 2013',
#  u'default_profile': False,
#  u'default_profile_image': False,
#  u'description': u"Direttore commerciale Tunu\xe9 - Editori dell'immaginario",
#  u'entities': {u'description': {u'urls': []},
#   u'url': {u'urls': [{u'display_url': u'tunue.com',
#      u'expanded_url': u'http://www.tunue.com',
#      u'indices': [0, 22],
#      u'url': u'http://t.co/1ZblFVBjbq'}]}},
#  u'favourites_count': 202,
#  u'follow_request_sent': False,
#  u'followers_count': 106,
#  u'following': True,
#  u'friends_count': 232,
#  u'geo_enabled': True,
#  u'id': 1647251948,
#  u'id_str': u'1647251948',
#  u'is_translation_enabled': False,
#  u'is_translator': False,
#  u'lang': u'it',
#  u'listed_count': 0,
#  u'location': u'Roma',
#  u'name': u'marcoruffobernardini',
#  u'notifications': False,
#  u'profile_background_color': u'C0DEED',
#  u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000156907059/kzteJgbg.jpeg',
#  u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000156907059/kzteJgbg.jpeg',
#  u'profile_background_tile': True,
#  u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000410746448/6dd7b4f7c55bd0867aeb3c9a226d3092_normal.jpeg',
#  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000410746448/6dd7b4f7c55bd0867aeb3c9a226d3092_normal.jpeg',
#  u'profile_link_color': u'00C368',
#  u'profile_sidebar_border_color': u'000000',
#  u'profile_sidebar_fill_color': u'DDEEF6',
#  u'profile_text_color': u'333333',
#  u'profile_use_background_image': True,
#  u'protected': False,
#  u'screen_name': u'marcoruffo85',
#  u'status': {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jun 29 10:09:00 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [116, 129],
#      u'text': u'RomanziTunu\xe9'}],
#    u'media': [{u'display_url': u'pic.twitter.com/SQBxy5JCdY',
#      u'expanded_url': u'http://twitter.com/maxcle/status/483176179151962112/photo/1',
#      u'id': 483176176521723904,
#      u'id_str': u'483176176521723904',
#      u'indices': [139, 140],
#      u'media_url': u'http://pbs.twimg.com/media/BrSWLC2CQAAkI5q.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BrSWLC2CQAAkI5q.jpg',
#      u'sizes': {u'large': {u'h': 386, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 226, u'resize': u'fit', u'w': 599},
#       u'small': {u'h': 128, u'resize': u'fit', u'w': 339},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 483176179151962112,
#      u'source_status_id_str': u'483176179151962112',
#      u'type': u'photo',
#      u'url': u'http://t.co/SQBxy5JCdY'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 9798572,
#      u'id_str': u'9798572',
#      u'indices': [3, 10],
#      u'name': u'MassimilianoClemente',
#      u'screen_name': u'maxcle'},
#     {u'id': 115025600,
#      u'id_str': u'115025600',
#      u'indices': [28, 42],
#      u'name': u'Iacopo Barison',
#      u'screen_name': u'iacopobarison'},
#     {u'id': 556852992,
#      u'id_str': u'556852992',
#      u'indices': [52, 68],
#      u'name': u'Tuttolibri Live',
#      u'screen_name': u'Tuttolibri_live'},
#     {u'id': 494076550,
#      u'id_str': u'494076550',
#      u'indices': [77, 88],
#      u'name': u'Corriere LaLettura ',
#      u'screen_name': u'La_Lettura'},
#     {u'id': 9224352,
#      u'id_str': u'9224352',
#      u'indices': [95, 108],
#      u'name': u'vanni santoni',
#      u'screen_name': u'vannisantoni'},
#     {u'id': 56341915,
#      u'id_str': u'56341915',
#      u'indices': [109, 115],
#      u'name': u'Tunu\xe9',
#      u'screen_name': u'tunue'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 483190389068034048,
#   u'id_str': u'483190389068034048',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'ro',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 2,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Jun 29 09:12:32 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [104, 117],
#       u'text': u'RomanziTunu\xe9'}],
#     u'media': [{u'display_url': u'pic.twitter.com/SQBxy5JCdY',
#       u'expanded_url': u'http://twitter.com/maxcle/status/483176179151962112/photo/1',
#       u'id': 483176176521723904,
#       u'id_str': u'483176176521723904',
#       u'indices': [118, 140],
#       u'media_url': u'http://pbs.twimg.com/media/BrSWLC2CQAAkI5q.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/BrSWLC2CQAAkI5q.jpg',
#       u'sizes': {u'large': {u'h': 386, u'resize': u'fit', u'w': 1024},
#        u'medium': {u'h': 226, u'resize': u'fit', u'w': 599},
#        u'small': {u'h': 128, u'resize': u'fit', u'w': 339},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/SQBxy5JCdY'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 115025600,
#       u'id_str': u'115025600',
#       u'indices': [16, 30],
#       u'name': u'Iacopo Barison',
#       u'screen_name': u'iacopobarison'},
#      {u'id': 556852992,
#       u'id_str': u'556852992',
#       u'indices': [40, 56],
#       u'name': u'Tuttolibri Live',
#       u'screen_name': u'Tuttolibri_live'},
#      {u'id': 494076550,
#       u'id_str': u'494076550',
#       u'indices': [65, 76],
#       u'name': u'Corriere LaLettura ',
#       u'screen_name': u'La_Lettura'},
#      {u'id': 9224352,
#       u'id_str': u'9224352',
#       u'indices': [83, 96],
#       u'name': u'vanni santoni',
#       u'screen_name': u'vannisantoni'},
#      {u'id': 56341915,
#       u'id_str': u'56341915',
#       u'indices': [97, 103],
#       u'name': u'Tunu\xe9',
#       u'screen_name': u'tunue'}]},
#    u'favorite_count': 4,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 483176179151962112,
#    u'id_str': u'483176179151962112',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'ro',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 2,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    u'text': u'Stalin + Bianca @iacopobarison: ieri su @Tuttolibri_live oggi su @La_Lettura. Ol\xe9! @vannisantoni @tunue #RomanziTunu\xe9 http://t.co/SQBxy5JCdY',
#    u'truncated': False},
#   u'source': u'<a href="https://twitter.com/download/android" rel="nofollow">Twitter for Android Tablets</a>',
#   u'text': u'RT @maxcle: Stalin + Bianca @iacopobarison: ieri su @Tuttolibri_live oggi su @La_Lettura. Ol\xe9! @vannisantoni @tunue #RomanziTunu\xe9 http://t.\u2026',
#   u'truncated': False},
#  u'statuses_count': 707,
#  u'time_zone': None,
#  u'url': u'http://t.co/1ZblFVBjbq',
#  u'utc_offset': None,
#  u'verified': False}

# %%
t.users.contributees(user_id=1647251948)
# Out:
# []

# %%
t.users.contributors(user_id=1647251948)
# Out:
# ---------------------------------------------------------------------------
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-64-c5fa51e2bfbb> in <module>()
# ----> 1 t.users.contributors(user_id=1647251948)
#
# /usr/local/lib/python2.7/dist-packages/twitter/api.pyc in __call__(self, **kwargs)
#     243
#     244         req = urllib_request.Request(uriBase, body, headers)
# --> 245         return self._handle_response(req, uri, arg_data, _timeout)
#     246
#     247     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# /usr/local/lib/python2.7/dist-packages/twitter/api.pyc in _handle_response(self, req, uri, arg_data, _timeout)
#     274                 return []
#     275             else:
# --> 276                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     277
#     278
#
# TwitterHTTPError: Twitter sent status 400 for URL: 1.1/users/contributors.json using parameters: (oauth_consumer_key=Sv66cbPiZrSWh2rXCHil6ysm7&oauth_nonce=5775706777497207807&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1404080647&oauth_token=2588171150-zfu0vk9L6qTiLzT3DGMfrHiE6Cro72AE3JhRrG4&oauth_version=1.0&user_id=1647251948&oauth_signature=Vr8hU3ocaCBTK3M29OqezCfL1Ic%3D)
# details: {"errors":[{"code":21,"message":"Contributors are not enabled for the specified user"}]}

# %%
r = t.favorites.list(user_id=1647251948)

# %%
print(r[0]['text'])
# Out:
# Ciao papà, oggi sono su @La_Lettura! @vannisantoni @maxcle @tunue http://t.co/WWvl9ZRj0x

# %%
t.application.rate_limit_status()
# Out:
# {u'rate_limit_context': {u'access_token': u'2588171150-zfu0vk9L6qTiLzT3DGMfrHiE6Cro72AE3JhRrG4'},
#  u'resources': {u'account': {u'/account/settings': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/account/verify_credentials': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'application': {u'/application/rate_limit_status': {u'limit': 180,
#     u'remaining': 179,
#     u'reset': 1404086288}},
#   u'blocks': {u'/blocks/ids': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/blocks/list': {u'limit': 15, u'remaining': 15, u'reset': 1404086288}},
#   u'direct_messages': {u'/direct_messages': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/direct_messages/sent': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/direct_messages/sent_and_received': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/direct_messages/show': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'favorites': {u'/favorites/list': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'followers': {u'/followers/ids': {u'limit': 15,
#     u'remaining': 14,
#     u'reset': 1404086131},
#    u'/followers/list': {u'limit': 15, u'remaining': 15, u'reset': 1404086288}},
#   u'friends': {u'/friends/following/ids': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/friends/following/list': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/friends/ids': {u'limit': 15, u'remaining': 15, u'reset': 1404086288},
#    u'/friends/list': {u'limit': 15, u'remaining': 15, u'reset': 1404086288}},
#   u'friendships': {u'/friendships/incoming': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/friendships/lookup': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/friendships/no_retweets/ids': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/friendships/outgoing': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/friendships/show': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288}},
#   u'geo': {u'/geo/id/:place_id': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/geo/reverse_geocode': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/geo/search': {u'limit': 15, u'remaining': 15, u'reset': 1404086288},
#    u'/geo/similar_places': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'help': {u'/help/configuration': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/help/languages': {u'limit': 15, u'remaining': 15, u'reset': 1404086288},
#    u'/help/privacy': {u'limit': 15, u'remaining': 15, u'reset': 1404086288},
#    u'/help/tos': {u'limit': 15, u'remaining': 15, u'reset': 1404086288}},
#   u'lists': {u'/lists/list': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/lists/members': {u'limit': 180, u'remaining': 180, u'reset': 1404086288},
#    u'/lists/members/show': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/lists/memberships': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/lists/ownerships': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/lists/show': {u'limit': 15, u'remaining': 15, u'reset': 1404086288},
#    u'/lists/statuses': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/lists/subscribers': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/lists/subscribers/show': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/lists/subscriptions': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'mutes': {u'/mutes/users/ids': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/mutes/users/list': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'saved_searches': {u'/saved_searches/destroy/:id': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/saved_searches/list': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/saved_searches/show/:id': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}},
#   u'search': {u'/search/tweets': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288}},
#   u'statuses': {u'/statuses/home_timeline': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/statuses/lookup': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/statuses/mentions_timeline': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/statuses/oembed': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/statuses/retweeters/ids': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/statuses/retweets/:id': {u'limit': 60,
#     u'remaining': 60,
#     u'reset': 1404086288},
#    u'/statuses/retweets_of_me': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/statuses/show/:id': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/statuses/user_timeline': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288}},
#   u'trends': {u'/trends/available': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/trends/closest': {u'limit': 15, u'remaining': 15, u'reset': 1404086288},
#    u'/trends/place': {u'limit': 15, u'remaining': 15, u'reset': 1404086288}},
#   u'users': {u'/users/contributees': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/users/contributors': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/users/lookup': {u'limit': 180, u'remaining': 180, u'reset': 1404086288},
#    u'/users/profile_banner': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/users/search': {u'limit': 180, u'remaining': 180, u'reset': 1404086288},
#    u'/users/show/:id': {u'limit': 180,
#     u'remaining': 180,
#     u'reset': 1404086288},
#    u'/users/suggestions': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/users/suggestions/:slug': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288},
#    u'/users/suggestions/:slug/members': {u'limit': 15,
#     u'remaining': 15,
#     u'reset': 1404086288}}}}

# %% [markdown]
# Python Twitter Tools
# ====================
#
# [![Build Status](https://travis-ci.org/sixohsix/twitter.svg)](https://travis-ci.org/sixohsix/twitter)
#
# The Minimalist Twitter API for Python is a Python API for Twitter,
# everyone's favorite Web 2.0 Facebook-style status updater for people
# on the go.
#
# Also included is a twitter command-line tool for getting your friends'
# tweets and setting your own tweet from the safety and security of your
# favorite shell and an IRC bot that can announce Twitter updates to an
# IRC channel.
#
# For more information, after installing the `twitter` package:
#
#  * import the `twitter` package and run help() on it
#  * run `twitter -h` for command-line tool help
#
#
# twitter - The Command-Line Tool
# -------------------------------
#
# The command-line tool lets you do some awesome things:
#
#  * view your tweets, recent replies, and tweets in lists
#  * view the public timeline
#  * follow and unfollow (leave) friends
#  * various output formats for tweet information
#
# The bottom line: type `twitter`, receive tweets.
#
#
#
# twitterbot - The IRC Bot
# ------------------------
#
# The IRC bot is associated with a twitter account (either your own account or an
# account you create for the bot). The bot announces all tweets from friends
# it is following. It can be made to follow or leave friends through IRC /msg
# commands.
#
#
# twitter-log
# -----------
#
# `twitter-log` is a simple command-line tool that dumps all public
# tweets from a given user in a simple text format. It is useful to get
# a complete offsite backup of all your tweets. Run `twitter-log` and
# read the instructions.
#
# twitter-archiver and twitter-follow
# -----------------------------------
#
# twitter-archiver will log all the tweets posted by any user since they
# started posting. twitter-follow will print a list of all of all the
# followers of a user (or all the users that user follows).
#
#
# Programming with the Twitter api classes
# ========================================
#
#
# The Twitter and TwitterStream classes are the key to building your own
# Twitter-enabled applications.
#
#
# The Twitter class
# -----------------
#
# The minimalist yet fully featured Twitter API class.
#
# Get RESTful data by accessing members of this class. The result
# is decoded python objects (lists and dicts).
#
# The Twitter API is documented at:
#
# **[http://dev.twitter.com/doc](http://dev.twitter.com/doc)**
#
#
# Examples::
#
# ```python
# from twitter import *
#
# # see "Authentication" section below for tokens and keys
# t = Twitter(
#             auth=OAuth(OAUTH_TOKEN, OAUTH_SECRET,
#                        CONSUMER_KEY, CONSUMER_SECRET)
#            )
#
# # Get your "home" timeline
# t.statuses.home_timeline()
#
# # Get a particular friend's timeline
# t.statuses.user_timeline(screen_name="billybob")
#
# # to pass in GET/POST parameters, such as `count`
# t.statuses.home_timeline(count=5)
#
# # to pass in the GET/POST parameter `id` you need to use `_id`
# t.statuses.oembed(_id=1234567890)
#
# # Update your status
# t.statuses.update(
#     status="Using @sixohsix's sweet Python Twitter Tools.")
#
# # Send a direct message
# t.direct_messages.new(
#     user="billybob",
#     text="I think yer swell!")
#
# # Get the members of tamtar's list "Things That Are Rad"
# t._("tamtar")._("things-that-are-rad").members()
#
# # Note how the magic `_` method can be used to insert data
# # into the middle of a call. You can also use replacement:
# t.user.list.members(user="tamtar", list="things-that-are-rad")
#
# # An *optional* `_timeout` parameter can also be used for API
# # calls which take much more time than normal or Twitter stops
# # responding for some reason
# t.users.lookup(screen_name=','.join(A_LIST_OF_100_SCREEN_NAMES), _timeout=1)
#
# # Overriding Method: GET/POST
# # you should not need to use this method as this library properly
# # detects whether GET or POST should be used, Nevertheless
# # to force a particular method, use `_method`
# t.statuses.oembed(_id=1234567890, _method='GET')
# ```
#
# Searching Twitter::
#
# ``` python
# # Search for the latest tweets about #pycon
# t.search.tweets(q="#pycon")
# ```
#
# Using the data returned
# -----------------------
#
# Twitter API calls return decoded JSON. This is converted into
# a bunch of Python lists, dicts, ints, and strings. For example::
#
# ```python
# x = twitter.statuses.home_timeline()
#
# # The first 'tweet' in the timeline
# x[0]
#
# # The screen name of the user who wrote the first 'tweet'
# x[0]['user']['screen_name']
# ```
#
# Getting raw XML data
# --------------------
#
# If you prefer to get your Twitter data in XML format, pass
# format="xml" to the Twitter object when you instantiate it::
#
# ```python
# twitter = Twitter(format="xml")
# ```
#
# The output will not be parsed in any way. It will be a raw string
# of XML.
#
#
# The TwitterStream class
# -----------------------
#
# The TwitterStream object is an interface to the Twitter Stream API
# (stream.twitter.com). This can be used pretty much the same as the
# Twitter class except the result of calling a method will be an
# iterator that yields objects decoded from the stream. For
# example::
#
# ```python
# twitter_stream = TwitterStream(auth=UserPassAuth('joe', 'joespassword'))
# iterator = twitter_stream.statuses.sample()
#
# for tweet in iterator:
#     # ...do something with this tweet...
# ```
#
# The iterator will yield tweets forever and ever (until the stream
# breaks at which point it raises a TwitterHTTPError.)
#
# The `block` parameter controls if the stream is blocking. Default
# is blocking (True). When set to False, the iterator will
# occasionally yield None when there is no available message.
#
# Per default the ``TwitterStream`` object uses
# [public streams](https://dev.twitter.com/docs/streaming-apis/streams/public).
# If you want to use one of the other
# [streaming APIs](https://dev.twitter.com/docs/streaming-apis), specify the URL
# manually:
#
# - [Public streams](https://dev.twitter.com/docs/streaming-apis/streams/public): stream.twitter.com
# - [User streams](https://dev.twitter.com/docs/streaming-apis/streams/user): userstream.twitter.com
# - [Site streams](https://dev.twitter.com/docs/streaming-apis/streams/site): sitestream.twitter.com
#
# Note that you require the proper
# [permissions](https://dev.twitter.com/docs/application-permission-model) to
# access these streams. E.g. for direct messages your
# [application](https://dev.twitter.com/apps) needs the "Read, Write & Direct
# Messages" permission.
#
# The following example demonstrates how to retrieve all new direct messages
# from the user stream:
#
# ```python
# auth = OAuth(
#     consumer_key='[your consumer key]',
#     consumer_secret='[your consumer secret]',
#     token='[your token]',
#     token_secret='[your token secret]'
# )
# twitter_userstream = TwitterStream(auth=auth, domain='userstream.twitter.com')
# for msg in twitter_userstream.user():
#     if 'direct_message' in msg:
#         print msg['direct_message']['text']
# ```
#
# Twitter Response Objects
# ------------------------
#
# Response from a Twitter request. Behaves like a list or a string
# (depending on requested format) but it has a few other interesting
# attributes.
#
# `headers` gives you access to the response headers as an
# httplib.HTTPHeaders instance. You can do
# `response.headers.getheader('h')` to retrieve a header.
#
# Authentication
# --------------
#
# You can authenticate with Twitter in three ways: NoAuth, OAuth, or
# UserPassAuth. Get help() on these classes to learn how to use them.
#
# OAuth is probably the most useful.
#
#
# Working with OAuth
# ------------------
#
# Visit the Twitter developer page and create a new application:
#
# **[https://dev.twitter.com/apps/new](https://dev.twitter.com/apps/new)**
#
# This will get you a CONSUMER_KEY and CONSUMER_SECRET.
#
# When users run your application they have to authenticate your app
# with their Twitter account. A few HTTP calls to Twitter are required
# to do this. Please see the twitter.oauth_dance module to see how this
# is done. If you are making a command-line app, you can use the
# oauth_dance() function directly.
#
# Performing the "oauth dance" gets you an oauth token and oauth secret
# that authenticate the user with Twitter. You should save these for
# later so that the user doesn't have to do the oauth dance again.
#
# read_token_file and write_token_file are utility methods to read and
# write OAuth token and secret key values. The values are stored as
# strings in the file. Not terribly exciting.
#
# Finally, you can use the OAuth authenticator to connect to Twitter. In
# code it all goes like this::
#
# ```python
# from twitter import *
#
# MY_TWITTER_CREDS = os.path.expanduser('~/.my_app_credentials')
# if not os.path.exists(MY_TWITTER_CREDS):
#     oauth_dance("My App Name", CONSUMER_KEY, CONSUMER_SECRET,
#                 MY_TWITTER_CREDS)
#
# oauth_token, oauth_secret = read_token_file(MY_TWITTER_CREDS)
#
# twitter = Twitter(auth=OAuth(
#     oauth_token, oauth_secret, CONSUMER_KEY, CONSUMER_SECRET))
#
# # Now work with Twitter
# twitter.statuses.update(status='Hello, world!')
# ```
#
#
# License
# =======
#
# Python Twitter Tools are released under an MIT License.
